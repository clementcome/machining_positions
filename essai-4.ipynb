# %%
# %load_ext autoreload
# %autoreload 2

# %%
from machining_positions.process import main

# %%
main("Champ Dragon Ladies - V2.svg", "test_output_2", 10, 1)
# Out:
#  59%|█████▉    | 26/44 [00:31<00:05,  3.47it/s]/home/clement/.pyenv/versions/3.9.17/envs/papa-bezier/lib/python3.9/site-packages/shapely/measurement.py:72: RuntimeWarning:
#
# invalid value encountered in distance
#
# /home/clement/.pyenv/versions/3.9.17/envs/papa-bezier/lib/python3.9/site-packages/shapely/measurement.py:72: RuntimeWarning:
#
# invalid value encountered in distance
#
# /home/clement/.pyenv/versions/3.9.17/envs/papa-bezier/lib/python3.9/site-packages/shapely/measurement.py:72: RuntimeWarning:
#
# invalid value encountered in distance
#
# /home/clement/.pyenv/versions/3.9.17/envs/papa-bezier/lib/python3.9/site-packages/shapely/measurement.py:72: RuntimeWarning:
#
# invalid value encountered in distance
#
# /home/clement/.pyenv/versions/3.9.17/envs/papa-bezier/lib/python3.9/site-packages/shapely/measurement.py:72: RuntimeWarning:
#
# invalid value encountered in distance
#
# ...
